# %% [markdown]
# <a href="https://colab.research.google.com/github/scudilio/Visualizacao_de_dados/blob/master/Formata%C3%A7%C3%A3o_Tabela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![texto alternativo](https://raw.githubusercontent.com/scudilio/Visualizacao_de_dados/master/imagens/capaIII.jpg)

# %% [markdown]
# #**Visualização de Dados em Python: Formatação de Tabela**
#
# Muitas vezes precisamos utilizar uma tabela para apresentar os resultados e é importante apresentar a tabela da forma mais informativa possível.
#
# No Python é possível customizar as tabelas da maneira desejada e da forma mais adequada. Nesse notebook apresento algumas opções de formatação de tabelas:
#
# * Mudando a cor da fonte.
# * Mundando a cor da célula.
# * Adicionando uma gráfico de barra na célula.
#
# Para fazer essas formatação utilizamos o comando 'style' da biblioteca Pandas.

# %% [markdown]
# ##Gerando os dados
#
# Para exemplificar as diversas maneiras de formatar uma tabela no Python geramos um pequeno conjunto de dados.

# %%
import numpy as np
import pandas as pd

# %%
notas = {'Alice': np.random.uniform(5, 10, 4).round(1),
              'Bruno': np.random.uniform(0, 7, 4).round(1),
              'Carol': np.random.uniform(3, 7, 4).round(1),
              'David': np.random.uniform(0, 10, 4).round(1),
              'Emily': np.random.uniform(8, 10, 4).round(1)}

# %%
provas = pd.DataFrame(notas)
provas.index = ['P1', 'P2', 'P3', 'P4']
df = provas.transpose()
df
# Out:
#         P1   P2   P3   P4
# Alice  7.3  7.8  5.4  5.1
# Bruno  6.0  3.9  6.5  4.6
# Carol  6.3  6.6  6.1  6.6
# David  9.7  8.5  8.6  0.9
# Emily  9.0  8.7  9.0  8.1

# %%
#descritiva do dataset
df.describe()
# Out:
#              P1        P2        P3        P4
# count  5.000000  5.000000  5.000000  5.000000
# mean   7.660000  7.100000  7.120000  5.060000
# std    1.634931  1.968502  1.589654  2.698703
# min    6.000000  3.900000  5.400000  0.900000
# 25%    6.300000  6.600000  6.100000  4.600000
# 50%    7.300000  7.800000  6.500000  5.100000
# 75%    9.000000  8.500000  8.600000  6.600000
# max    9.700000  8.700000  9.000000  8.100000

# %%
#Analisando a descritiva pela linha
df.transpose().describe()
# Out:
#           Alice     Bruno     Carol     David     Emily
# count  4.000000  4.000000  4.000000  4.000000  4.000000
# mean   6.400000  5.250000  6.400000  6.925000  8.700000
# std    1.349074  1.206924  0.244949  4.053291  0.424264
# min    5.100000  3.900000  6.100000  0.900000  8.100000
# 25%    5.325000  4.425000  6.250000  6.600000  8.550000
# 50%    6.350000  5.300000  6.450000  8.550000  8.850000
# 75%    7.425000  6.125000  6.600000  8.875000  9.000000
# max    7.800000  6.500000  6.600000  9.700000  9.000000

# %% [markdown]
# ##Adicionando novas variáveis na Tabela
#
# Muitas vezes é necessário criar novas variáveis, a seguir mostramos dois exemplos de como podemos adicionar novas variáveis em um conjunto de dados.

# %%
#criado uma variável média
df['MF'] = df.mean(axis = 1).round(1)
df
# Out:
#         P1   P2   P3   P4   MF
# Alice  7.3  7.8  5.4  5.1  6.4
# Bruno  6.0  3.9  6.5  4.6  5.2
# Carol  6.3  6.6  6.1  6.6  6.4
# David  9.7  8.5  8.6  0.9  6.9
# Emily  9.0  8.7  9.0  8.1  8.7

# %%
#criando uma variável situação
def aux(x):
    if x >= 5:
        return 'Aprovado'
    else:
        return 'Reprovado'

df['Situação'] = df['MF'].apply(aux)
df
# Out:
#         P1   P2   P3   P4   MF  Situação
# Alice  7.3  7.8  5.4  5.1  6.4  Aprovado
# Bruno  6.0  3.9  6.5  4.6  5.2  Aprovado
# Carol  6.3  6.6  6.1  6.6  6.4  Aprovado
# David  9.7  8.5  8.6  0.9  6.9  Aprovado
# Emily  9.0  8.7  9.0  8.1  8.7  Aprovado

# %% [markdown]
# #**Formatando a Cor da Letra em uma Tabela**
#
# Numa tabela com as informações das notas é importante realçar os alunos com baixo rendimento e os alunos com um bom rendimento.
#
# Para isso criamos uma função para definir alguns critérios, aqui vamos mudar a cor da fonte para vermelho para os alunos que tiveram nota inferior a 5 e azul para os alunos com nota acima ou igual a 5.
#
# Criamos uma função para colorir a situação dos alunos (aprovado ou reprovado).
#
# Depois utilizamos o 'style.applymap' para aplicar as funções criadas. O comando 'format' utlizamos para formatar os números.

# %%
def cores (notas):
    color = 'red' if notas <5 else 'blue'
    return 'color: %s' % color 
 
def cor(val):
    return 'color: %s' % ('blue' if val in {"Aprovado"} else 'red')

df1 = df.style.applymap(cores, subset=['P1','P2','P3','P4','MF'])\
            .applymap(cor, subset=['Situação'])\
            .format({"P1":"{:50,.2f}",
                  "P2":"{:50,.2f}",
                  "P3":"{:50,.2f}",
                  "P4":"{:50,.2f}",
                "MF":"{:50,.2f}"})
df1
# Out:
# <style  type="text/css" >
#     #T_fa8475d0_7a09_11ec_8884_631879159b53row0_col0 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row0_col1 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row0_col2 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row0_col3 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row0_col4 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row0_col5 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row1_col0 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row1_col1 {
#             color:  red;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row1_col2 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row1_col3 {
#             color:  red;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row1_col4 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row1_col5 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row2_col0 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row2_col1 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row2_col2 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row2_col3 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row2_col4 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row2_col5 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row3_col0 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row3_col1 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row3_col2 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row3_col3 {
#             color:  red;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row3_col4 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row3_col5 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row4_col0 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row4_col1 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row4_col2 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row4_col3 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row4_col4 {
#             color:  blue;
#         }    #T_fa8475d0_7a09_11ec_8884_631879159b53row4_col5 {
#             color:  blue;
#         }</style><table id="T_fa8475d0_7a09_11ec_8884_631879159b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P1</th>        <th class="col_heading level0 col1" >P2</th>        <th class="col_heading level0 col2" >P3</th>        <th class="col_heading level0 col3" >P4</th>        <th class="col_heading level0 col4" >MF</th>        <th class="col_heading level0 col5" >Situação</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fa8475d0_7a09_11ec_8884_631879159b53level0_row0" class="row_heading level0 row0" >Alice</th>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row0_col0" class="data row0 col0" >                                              7.30</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row0_col1" class="data row0 col1" >                                              7.80</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row0_col2" class="data row0 col2" >                                              5.40</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row0_col3" class="data row0 col3" >                                              5.10</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row0_col4" class="data row0 col4" >                                              6.40</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row0_col5" class="data row0 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_fa8475d0_7a09_11ec_8884_631879159b53level0_row1" class="row_heading level0 row1" >Bruno</th>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row1_col0" class="data row1 col0" >                                              6.00</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row1_col1" class="data row1 col1" >                                              3.90</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row1_col2" class="data row1 col2" >                                              6.50</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row1_col3" class="data row1 col3" >                                              4.60</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row1_col4" class="data row1 col4" >                                              5.20</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row1_col5" class="data row1 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_fa8475d0_7a09_11ec_8884_631879159b53level0_row2" class="row_heading level0 row2" >Carol</th>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row2_col0" class="data row2 col0" >                                              6.30</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row2_col1" class="data row2 col1" >                                              6.60</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row2_col2" class="data row2 col2" >                                              6.10</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row2_col3" class="data row2 col3" >                                              6.60</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row2_col4" class="data row2 col4" >                                              6.40</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row2_col5" class="data row2 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_fa8475d0_7a09_11ec_8884_631879159b53level0_row3" class="row_heading level0 row3" >David</th>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row3_col0" class="data row3 col0" >                                              9.70</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row3_col1" class="data row3 col1" >                                              8.50</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row3_col2" class="data row3 col2" >                                              8.60</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row3_col3" class="data row3 col3" >                                              0.90</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row3_col4" class="data row3 col4" >                                              6.90</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row3_col5" class="data row3 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_fa8475d0_7a09_11ec_8884_631879159b53level0_row4" class="row_heading level0 row4" >Emily</th>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row4_col0" class="data row4 col0" >                                              9.00</td>
#                         <td id="T_fa8475d0_7a09_11ec_8884_631879159b53row4_col1" class="data row4 col1" >                                              8.70</td>

# %% [markdown]
# ##**Formatando a Cor da Célula em uma Tabela**
#
# E se ao invés de mudar a cor da fonte, o interesse for em colorir a célula (cor de fundo), preciso aplicar a cor no background. Para isso utilizo o comando 'background_gradient',

# %%
df.style.format({"P1":"{:50,.2f}",
                  "P2":"{:50,.2f}",
                  "P3":"{:50,.2f}",
                  "P4":"{:50,.2f}",
                "MF":"{:50,.2f}"})\
        .background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col0 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col1 {
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col3 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col4 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col2 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col3 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col0 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col1 {
#             background-color:  #56a0ce;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col2 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col3 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col4 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col1 {
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col2 {
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col4 {
#             background-color:  #71b1d7;
#             color:  #000000;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row4_col0 {
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row4_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row4_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row4_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_680b5cd6_7a0a_11ec_8884_631879159b53row4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_680b5cd6_7a0a_11ec_8884_631879159b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P1</th>        <th class="col_heading level0 col1" >P2</th>        <th class="col_heading level0 col2" >P3</th>        <th class="col_heading level0 col3" >P4</th>        <th class="col_heading level0 col4" >MF</th>        <th class="col_heading level0 col5" >Situação</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_680b5cd6_7a0a_11ec_8884_631879159b53level0_row0" class="row_heading level0 row0" >Alice</th>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col0" class="data row0 col0" >                                              7.30</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col1" class="data row0 col1" >                                              7.80</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col2" class="data row0 col2" >                                              5.40</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col3" class="data row0 col3" >                                              5.10</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col4" class="data row0 col4" >                                              6.40</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row0_col5" class="data row0 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_680b5cd6_7a0a_11ec_8884_631879159b53level0_row1" class="row_heading level0 row1" >Bruno</th>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col0" class="data row1 col0" >                                              6.00</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col1" class="data row1 col1" >                                              3.90</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col2" class="data row1 col2" >                                              6.50</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col3" class="data row1 col3" >                                              4.60</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col4" class="data row1 col4" >                                              5.20</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row1_col5" class="data row1 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_680b5cd6_7a0a_11ec_8884_631879159b53level0_row2" class="row_heading level0 row2" >Carol</th>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col0" class="data row2 col0" >                                              6.30</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col1" class="data row2 col1" >                                              6.60</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col2" class="data row2 col2" >                                              6.10</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col3" class="data row2 col3" >                                              6.60</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col4" class="data row2 col4" >                                              6.40</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row2_col5" class="data row2 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_680b5cd6_7a0a_11ec_8884_631879159b53level0_row3" class="row_heading level0 row3" >David</th>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col0" class="data row3 col0" >                                              9.70</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col1" class="data row3 col1" >                                              8.50</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col2" class="data row3 col2" >                                              8.60</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col3" class="data row3 col3" >                                              0.90</td>
#                         <td id="T_680b5cd6_7a0a_11ec_8884_631879159b53row3_col4" class="data row3 col4" >

# %% [markdown]
# E se você quiser mudar a cor da célula, utilizando um critério próprio, é preciso criar uma função definindo esse critério e no 'return' aplicamos a cor no background ('background-color').

# %%
def cores (notas):
    color = '#FF9185' if notas <5 else 'lightblue'
    return 'background-color: %s' % color 

df1 = df.style.applymap(cores, subset=['P1','P2','P3','P4','MF'])\
            .applymap(cor, subset=['Situação'])\
            .format({"P1":"{:50,.2f}",
                  "P2":"{:50,.2f}",
                  "P3":"{:50,.2f}",
                  "P4":"{:50,.2f}",
                "MF":"{:50,.2f}"})
df1
# Out:
# <style  type="text/css" >
#     #T_855548e2_7a0a_11ec_8884_631879159b53row0_col0 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row0_col1 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row0_col2 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row0_col3 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row0_col4 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row0_col5 {
#             color:  blue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row1_col0 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row1_col1 {
#             background-color:  #FF9185;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row1_col2 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row1_col3 {
#             background-color:  #FF9185;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row1_col4 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row1_col5 {
#             color:  blue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row2_col0 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row2_col1 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row2_col2 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row2_col3 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row2_col4 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row2_col5 {
#             color:  blue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row3_col0 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row3_col1 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row3_col2 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row3_col3 {
#             background-color:  #FF9185;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row3_col4 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row3_col5 {
#             color:  blue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row4_col0 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row4_col1 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row4_col2 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row4_col3 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row4_col4 {
#             background-color:  lightblue;
#         }    #T_855548e2_7a0a_11ec_8884_631879159b53row4_col5 {
#             color:  blue;
#         }</style><table id="T_855548e2_7a0a_11ec_8884_631879159b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P1</th>        <th class="col_heading level0 col1" >P2</th>        <th class="col_heading level0 col2" >P3</th>        <th class="col_heading level0 col3" >P4</th>        <th class="col_heading level0 col4" >MF</th>        <th class="col_heading level0 col5" >Situação</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_855548e2_7a0a_11ec_8884_631879159b53level0_row0" class="row_heading level0 row0" >Alice</th>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row0_col0" class="data row0 col0" >                                              7.30</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row0_col1" class="data row0 col1" >                                              7.80</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row0_col2" class="data row0 col2" >                                              5.40</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row0_col3" class="data row0 col3" >                                              5.10</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row0_col4" class="data row0 col4" >                                              6.40</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row0_col5" class="data row0 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_855548e2_7a0a_11ec_8884_631879159b53level0_row1" class="row_heading level0 row1" >Bruno</th>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row1_col0" class="data row1 col0" >                                              6.00</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row1_col1" class="data row1 col1" >                                              3.90</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row1_col2" class="data row1 col2" >                                              6.50</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row1_col3" class="data row1 col3" >                                              4.60</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row1_col4" class="data row1 col4" >                                              5.20</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row1_col5" class="data row1 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_855548e2_7a0a_11ec_8884_631879159b53level0_row2" class="row_heading level0 row2" >Carol</th>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row2_col0" class="data row2 col0" >                                              6.30</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row2_col1" class="data row2 col1" >                                              6.60</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row2_col2" class="data row2 col2" >                                              6.10</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row2_col3" class="data row2 col3" >                                              6.60</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row2_col4" class="data row2 col4" >                                              6.40</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row2_col5" class="data row2 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_855548e2_7a0a_11ec_8884_631879159b53level0_row3" class="row_heading level0 row3" >David</th>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row3_col0" class="data row3 col0" >                                              9.70</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row3_col1" class="data row3 col1" >                                              8.50</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row3_col2" class="data row3 col2" >                                              8.60</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row3_col3" class="data row3 col3" >                                              0.90</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row3_col4" class="data row3 col4" >                                              6.90</td>
#                         <td id="T_855548e2_7a0a_11ec_8884_631879159b53row3_col5" class="data row3 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_855548e2_7a0a_11ec_8884_

# %% [markdown]
# ##**Adicionando uma Barra nas Linhas da Tabela**
#
# Uma maneira interessante de formatar uma tabela é acrescentando uma barra nas células. Para isso utilizamos o comando 'style.bar'.

# %%
df.style.format({"P1":"{:20,.2f}",
                  "P2":"{:20,.2f}",
                  "P3":"{:20,.2f}",
                  "P4":"{:20,.2f}",
                  "MF":"{:20,.2f}"})\
          .bar(subset=["P1",], color='lightgreen',vmin=0,vmax=10)\
          .bar(subset=["P2",], color='#ee1f5f',vmin=0)\
          .bar(subset=["P3",], color='#FFA07A',vmin=0)\
          .bar(subset=["P4",], color='lightblue',vmin=0)\
          .bar(subset=["MF",], color='#c8a2c8 ',vmin=0)\
# Out:
# <style  type="text/css" >
#     #T_94dc819a_7a0a_11ec_8884_631879159b53row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 73.0%, transparent 73.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 89.7%, transparent 89.7%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 60.0%, transparent 60.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 63.0%, transparent 63.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c8a2c8  73.6%, transparent 73.6%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 60.0%, transparent 60.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 44.8%, transparent 44.8%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 72.2%, transparent 72.2%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 56.8%, transparent 56.8%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c8a2c8  59.8%, transparent 59.8%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 63.0%, transparent 63.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 75.9%, transparent 75.9%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 67.8%, transparent 67.8%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 81.5%, transparent 81.5%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c8a2c8  73.6%, transparent 73.6%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 97.0%, transparent 97.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 97.7%, transparent 97.7%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 95.6%, transparent 95.6%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 11.1%, transparent 11.1%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c8a2c8  79.3%, transparent 79.3%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 90.0%, transparent 90.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 100.0%, transparent 100.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 100.0%, transparent 100.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_94dc819a_7a0a_11ec_8884_631879159b53row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c8a2c8  100.0%, transparent 100.0%);
#         }</style><table id="T_94dc819a_7a0a_11ec_8884_631879159b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P1</th>        <th class="col_heading level0 col1" >P2</th>        <th class="col_heading level0 col2" >P3</th>        <th class="col_heading level0 col3" >P4</th>        <th class="col_heading level0 col4" >MF</th>        <th class="col_heading level0 col5" >Situação</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94dc819a_7a0a_11ec_8884_631879159b53level0_row0" class="row_heading level0 row0" >Alice</th>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row0_col0" class="data row0 col0" >                7.30</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row0_col1" class="data row0 col1" >                7.80</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row0_col2" class="data row0 col2" >                5.40</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row0_col3" class="data row0 col3" >                5.10</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row0_col4" class="data row0 col4" >                6.40</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row0_col5" class="data row0 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_94dc819a_7a0a_11ec_8884_631879159b53level0_row1" class="row_heading level0 row1" >Bruno</th>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row1_col0" class="data row1 col0" >                6.00</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row1_col1" class="data row1 col1" >                3.90</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row1_col2" class="data row1 col2" >                6.50</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row1_col3" class="data row1 col3" >                4.60</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row1_col4" class="data row1 col4" >                5.20</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row1_col5" class="data row1 col5" >Aprovado</td>
#             </tr>
#             <tr>
#                         <th id="T_94dc819a_7a0a_11ec_8884_631879159b53level0_row2" class="row_heading level0 row2" >Carol</th>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row2_col0" class="data row2 col0" >                6.30</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row2_col1" class="data row2 col1" >                6.60</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row2_col2" class="data row2 col2" >                6.10</td>
#                         <td id="T_94dc819a_7a0a_11ec_8884_631879159b53row2_col3" class="dat

# %%
df.style.format({"P1":"{:20,.2f}",
                  "P2":"{:20,.2f}",
                  "P3":"{:20,.2f}",
                  "P4":"{:20,.2f}",
                  "MF":"{:20,.2f}"})\
          .bar(subset=["P1","P2","P3","P4","MF"], color='#FF9185 ',vmin=0,vmax=5)\
          .bar(subset=["P1","P2","P3","P4","MF"], color='lightblue',vmin=5,vmax=10)\
# Out:
# <style  type="text/css" >
#     #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 46.0%, transparent 46.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 56.0%, transparent 56.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 8.0%, transparent 8.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 2.0%, transparent 2.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 28.0%, transparent 28.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 20.0%, transparent 20.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  78.0%, transparent 78.0%);
#             width:  10em;
#              height:  80%;
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 30.0%, transparent 30.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  92.0%, transparent 92.0%);
#             width:  10em;
#              height:  80%;
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 4.0%, transparent 4.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 26.0%, transparent 26.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 32.0%, transparent 32.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 22.0%, transparent 22.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 32.0%, transparent 32.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 28.0%, transparent 28.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 94.0%, transparent 94.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 70.0%, transparent 70.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 72.0%, transparent 72.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  18.0%, transparent 18.0%);
#             width:  10em;
#              height:  80%;
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 38.0%, transparent 38.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 80.0%, transparent 80.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 74.0%, transparent 74.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 80.0%, transparent 80.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FF9185  100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 62.0%, transparent 62.0%);
#         }    #T_a0cc0f5c_7a0a_11ec_8884_631879159b53row4_col4 {
#             width:  10em;
#              height:

# %% [markdown]
# ##**Links Úteis**
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html
